# %% [markdown]
# <a href="https://colab.research.google.com/github/Arishakarim8/Assignment_4/blob/main/Home_Work_Projects/Assignments_00_to_05/00_intro_python/05_triangle_perimeter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def triangle():
  side1 = float(input("What is the length of side 1? "))
  side2 = float(input("What is the length of side 2? "))
  side3 = float(input("What is the length of side 3? "))
  perimeter = side1 + side2 + side3
  print("The perimeter of the triangle is", perimeter)

triangle()
# Out:
# What is the length of side 1? 5.5
# What is the length of side 2? 6.5
# What is the length of side 3? 3.5
# The perimeter of the triangle is 15.5
