# %% [markdown]
# <a href="https://colab.research.google.com/github/Arishakarim8/Assignment_4/blob/main/Home_Work_Projects/Assignments_00_to_05/00_intro_python/02__agreement_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def favorite_animal():
  favorite_animal = str(input("What's your favorite animal? "))
  print("My favorite animal is also " + str(favorite_animal) +"!")

if __name__ == '__main__':
  favorite_animal()
# Out:
# What's your favorite animal? cat
# My favorite animal is also cat!
