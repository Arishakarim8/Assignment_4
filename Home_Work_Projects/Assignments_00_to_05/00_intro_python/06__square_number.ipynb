# %% [markdown]
# <a href="https://colab.research.google.com/github/Arishakarim8/Assignment_4/blob/main/Home_Work_Projects/Assignments_00_to_05/00_intro_python/06__square_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def square():
  square = float(input("Type a number to see its square: "))
  print("The square of" , square , "is :" , str(square ** 2))

square()
# Out:
# Type a number to see its square: 5
# The square of 5.0 is : 25.0
