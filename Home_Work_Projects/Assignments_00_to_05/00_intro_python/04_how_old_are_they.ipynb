# %% [markdown]
# <a href="https://colab.research.google.com/github/Arishakarim8/Assignment_4/blob/main/Home_Work_Projects/Assignments_00_to_05/00_intro_python/04_how_old_are_they.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
  Anton : int = 21
  Beth : int = 6 + Anton
  Chen : int = 20 + Beth
  Drew : int = Chen + Anton
  Ethan : int = Chen
  print("Anton is" , str(Anton) )
  print("Beth is" , str(Beth))
  print("Chen is" , str(Chen))
  print("Drew is" , str(Drew))
  print("Ethan is" , str(Ethan))

main()
# Out:
# Anton is 21
# Beth is 27
# Chen is 47
# Drew is 68
# Ethan is 47
