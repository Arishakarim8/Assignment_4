# %%
SENTENCE_START : str = "Panaversity is fun , I learned to program and used Python to make"

def mad_libs():
  adjective : str = input("Please type an adjective and press enter. ")
  noun : str = input("Please type a noun and press enter. ")
  verb : str = input("Please type a verb and press enter. ")
  print(SENTENCE_START + " " + adjective + " " + noun + " "  + verb)

mad_libs()
# Out:
# Please type an adjective and press enter .big
# Please type a noun and press enter. big
# Please type a verb and press enter. big
# Panaversity is fun , I learned to program and used Python to make big big big
