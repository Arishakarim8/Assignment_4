# %% [markdown]
# <a href="https://colab.research.google.com/github/Arishakarim8/Assignment_4/blob/main/Home_Work_Projects/Assignments_00_to_05/01_expression/01_dicesimulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

NUM_SIDES = 6

def roll_dice():
  die1 : int = random.randint(1 , NUM_SIDES)
  die2 : int = random.randint(1 , NUM_SIDES)
  total : int = die1 + die2
  print("Total of two dice: " , total)

def main():
  die1 : int = 10
  print("Die1 in main() starts as: " , die1)
  roll_dice()
  roll_dice()
  roll_dice()
  print("Die1 in main() is: " , die1)

main()
# Out:
# Die1 in main() starts as:  10
# Total of two dice:  8
# Total of two dice:  8
# Total of two dice:  7
# Die1 in main() is:  10
